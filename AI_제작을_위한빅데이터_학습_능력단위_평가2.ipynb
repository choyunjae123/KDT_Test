# %%
# matplotlib에서 한글폰트를 사용하기 위한 코드 작성
# !pip install matplotlib
import matplotlib.pyplot as plt

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

plt.rc('font', family='NanumBarunGothic')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# ...

# %%
# 사용데이터
# 소상공인시장진흥공단_상가(상권)정보
# https://www.data.go.kr/data/15083033/fileData.do
# 위 URL을 통해 CSV파일 다운로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pandas
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# 구글 드라이브와 연동
# CSV파일들을 읽어 각 지역별로 저장
# !pip install pandas
import pandas as pd
# 23년 3월
df_gangwon = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_강원_202303.csv')
df_gyeongi = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경기_202303.csv')
df_gyeongnam = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경남_202303.csv')
df_gyeongbuk = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경북_202303.csv')
df_gwangju = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_광주_202303.csv')
df_daegu = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_대구_202303.csv')
df_daejeon = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_대전_202303.csv')
df_busan = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_부산_202303.csv')
df_seoul = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_서울_202303.csv')
df_sejong = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_세종_202303.csv')
df_ulsan = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_울산_202303.csv')
df_incheon = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_인천_202303.csv')
df_jeonnam = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_전남_202303.csv')
df_jeonbuk = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_전북_202303.csv')
df_jeju = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_제주_202303.csv')
df_chungnam = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_충남_202303.csv')
df_chungbuk = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_충북_202303.csv')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# <ipython-input-6-8a1994499329>:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gangwon = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_강원_202303.csv')
# <ipython-input-6-8a1994499329>:7: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gyeongi = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경기_202303.csv')
# <ipython-input-6-8a1994499329>:8: DtypeWarning: Columns (2,35) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df_all = pd.concat([df_gangwon, df_gyeongi, df_gyeongnam, df_gyeongbuk, df_gwangju, df_daegu, df_daejeon, df_busan, df_seoul, df_sejong, df_ulsan, df_incheon, df_jeonnam, df_jeonbuk, df_jeju, df_chungnam, df_chungbuk]).reset_index(drop=True)

# %%
# 22년 9월
df_gangwon22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_강원_202209.csv')
df_gyeongi22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경기_202209.csv')
df_gyeongnam22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경남_202209.csv')
df_gyeongbuk22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경북_202209.csv')
df_gwangju22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_광주_202209.csv')
df_daegu22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_대구_202209.csv')
df_daejeon22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_대전_202209.csv')
df_busan22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_부산_202209.csv')
df_seoul22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_서울_202209.csv')
df_sejong22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_세종_202209.csv')
df_ulsan22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_울산_202209.csv')
df_incheon22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_인천_202209.csv')
df_jeonnam22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_전남_202209.csv')
df_jeonbuk22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_전북_202209.csv')
df_jeju22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_제주_202209.csv')
df_chungnam22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_충남_202209.csv')
df_chungbuk22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_충북_202209.csv')
# Out:
# <ipython-input-8-01ecf70b8e53>:4: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gyeongnam22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경남_202209.csv')
# <ipython-input-8-01ecf70b8e53>:5: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gyeongbuk22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경북_202209.csv')
# <ipython-input-8-01ecf70b8e53>:12: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ulsan22 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_울산_202209.csv')
# ...

# %%
df_all22 = pd.concat([df_gangwon22, df_gyeongi22, df_gyeongnam22, df_gyeongbuk22, df_gwangju22, df_daegu22, df_daejeon22, df_busan22, df_seoul22, df_sejong22, df_ulsan22, df_incheon22, df_jeonnam22, df_jeonbuk22, df_jeju22, df_chungnam22, df_chungbuk22]).reset_index(drop=True)

# %%
# 사용데이터
# https://www.data.go.kr/data/15083033/fileData.do // 연도는 가장 최신버전으로
# 위 URL을 통해 주기성 과거 데이터 CSV파일 다운로드

# 21년 12월
df_gangwon21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_강원_202112.csv')
df_gyeongi21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경기_202112.csv')
df_gyeongnam21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경남_202112.csv')
df_gyeongbuk21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경북_202112.csv')
df_gwangju21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_광주_202112.csv')
df_daegu21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_대구_202112.csv')
df_daejeon21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_대전_202112.csv')
df_busan21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_부산_202112.csv')
df_seoul21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_서울_202112.csv')
df_sejong21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_세종_202112.csv')
df_ulsan21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_울산_202112.csv')
df_incheon21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_인천_202112.csv')
df_jeonnam21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_전남_202112.csv')
df_jeonbuk21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_전북_202112.csv')
df_jeju21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_제주_202112.csv')
df_chungnam21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_충남_202112.csv')
df_chungbuk21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_충북_202112.csv')
# Out:
# <ipython-input-10-18fc0e26eab2>:8: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gyeongnam21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경남_202112.csv')
# <ipython-input-10-18fc0e26eab2>:9: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gyeongbuk21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경북_202112.csv')
# <ipython-input-10-18fc0e26eab2>:11: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_daegu21 = pd.read_csv('/content/drive/MyDrive/0531_test/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_대구_202112.csv')
# ...

# %%
df_all21 = pd.concat([df_gangwon21, df_gyeongi21, df_gyeongnam21, df_gyeongbuk21, df_gwangju21, df_daegu21, df_daejeon21, df_busan21, df_seoul21, df_sejong21, df_ulsan21, df_incheon21, df_jeonnam21, df_jeonbuk21, df_jeju21, df_chungnam21, df_chungbuk21]).reset_index(drop=True)

# %%
# 아래 질문의 답을 증명하기 위해 데이터 분석과정을 작성하세요(각 20점)

# 1. 맥도날드 매장 수는 계속 줄어들고 있을까? (201709 ~ 2023-05) 
#(17년 9월부터의 파일이 용량 및 메모리의 문제로 삽입이 되지 않는 상황이라 '21년 12월', '22년 9월', '23년 3월' 3개의 파일로 하여 분석했습니다.)


 # 21년 12월 전국 맥도날드의 수: 476개
 # 22년 9월 전국 맥도날드의 수: 474개
 # 23년 3월 전국 맥도날드의 수: 406개

# 아래의 그래프와 같이 꾸준히 매장 수 그래프가 우하향하는 모습을 볼 수 있다. 이에 따라 맥도날드 매장 수는 점점 감소하고 있다는 것을 추론할 수 있다.

# %%
# 21년 12월의 맥도날드 매장 수를 구하는 방법
df_mcdonald21 = df_all21['상호명'].str.contains(r'맥도날드')
df_mcdonald21.value_counts()
# Out:
# False    2189870
# True         476
# Name: 상호명, dtype: int64

# %%
# 22년 9월의 맥도날드 매장 수를 구하는 방법
df_mcdonald22 = df_all22['상호명'].str.contains(r'맥도날드')
df_mcdonald22.value_counts()
# Out:
# False    2446296
# True         474
# Name: 상호명, dtype: int64

# %%
# 23년 3월의 맥도날드 매장 수를 구하는 방법
df_mcdonald = df_all['상호명'].str.contains(r'맥도날드')
df_mcdonald.value_counts()
# Out:
# False    2443931
# True         406
# Name: 상호명, dtype: int64

# %%
# 해당 내용이 포함된 꺾은선그래프
plt.title('전국 맥도날드 매장 수 추이', fontsize=30)
plt.plot(['21년12월','22년9월','23년3월'],[476,474,406], color='r', marker='o')
plt.ylim(400,490)
plt.grid()  
plt.show()

# %%
# 2. 버거킹은 맥도날드의 매장수를 넘어섰을까? (2023-05현재)

# 맥도날드 매장 수: 406개
# 버거킹 매장 수: 94개

# 아래 막대그래프에서도 볼 수 있듯이 맥도날드의 매장 수는 406개이고, 버거킹의 매장 수는 94개로 거의 4배에 가까운 차이를 보이고 있다.
# 데이터에서 볼 수 있듯 버거킹은 맥도날드의 매장 수를 넘어서지 못했다는 사실을 알 수 있다.

# %%
# 현재 맥도날드 매장 수를 구하는 방법
df_mcdonald = df_all['상호명'].str.contains(r'맥도날드')
df_mcdonald.value_counts()
# Out:
# False    2443931
# True         406
# Name: 상호명, dtype: int64

# %%
# 현재 버거킹 매장 수를 구하는 방법
df_burgerking = df_all['상호명'].str.contains(r'버거킹')
df_burgerking.value_counts()
# Out:
# False    2444243
# True          94
# Name: 상호명, dtype: int64

# %%
# 해당 내용이 포함된 막대그래프
x = ['버거킹', '맥도날드']
y = [94, 406]

plt.figure(figsize=(5,8))
plt.bar(x, y, alpha=0.7, color='red')
plt.title('버거킹 vs 맥도날드', fontsize=25)
plt.ylabel('점포 수')
plt.show()

# %%
# 3. 패스트푸드 매장(롯데리아, 맥도날드, 버거킹, 맘스터치)은 어느 지역에 많이 분포할까? (시도)

# 롯데리아: 경기도 (264개)
# 맥도날드: 경기도 (97개)
# 버거킹: 경상북도 (14개)
# 맘스터치: 경기도 (290개)

# 아래의 산포도에서 볼 수 있듯이 서울 및 수도권부근에 패스트푸드 매장이 집중되어있는 모습을 볼 수 있다.
# 실제로 데이터를 출력하여 확인해 본 결과 경기도 부근에 가장 많이 몰려있는 것을 확인 할 수 있었다.

# %%
# 전국 패스트푸드 매장의 리스트를 구하는 방법
fastfood = ['롯데리아', '맥도날드', '버거킹', '맘스터치']

df_fastfood = df_all.copy()
df_fastfood['상호명'] = df_fastfood['상호명'].str.extract(r'({})'.format('|'.join(fastfood)))[0]
df_fastfood = df_fastfood.dropna(subset=['상호명']).iloc[:,[1,12,37,38]].reset_index(drop=True)
df_fastfood
# Out:
#        상호명   시도명          경도         위도
# 0     맘스터치   강원도  129.108406  37.491688
# 1     롯데리아   강원도  127.833470  37.320740
# 2     맘스터치   강원도  128.392948  37.367666
# 3     맘스터치   강원도  128.878771  37.769023
# 4     맘스터치   강원도  127.739060  37.883135
# ...    ...   ...         ...        ...
# 2883  롯데리아  충청북도  127.824494  37.016611
# 2884  맘스터치  충청북도  127.583958  36.793314
# 2885  맘스터치  충청북도  127.317474  36.620325
# 2886  맘스터치  충청북도  127.317474  36.620325
# 2887  맘스터치  충청북도  127.902414  37.028623
#
# [2888 rows x 4 columns]

# %%
# 전국 패스트푸드 매장의 브랜드별 지역별 갯수를 구하는 방법
df_fastfood.groupby(['상호명',
'시도명'])['상호명'].count()
# Out:
# 상호명   시도명
# 롯데리아  강원도       41
#       경기도      264
#       경상남도      69
#       경상북도      58
#       광주광역시     29
#               ...
# 버거킹   인천광역시      3
#       전라남도       6
#       전라북도       7
#       충청남도       6
#       충청북도       9
# Name: 상호명, Length: 66, dtype: int64

# %%
# 해당 내용이 포함된 산포도
plt.figure(figsize=(10,8))
sns.scatterplot(data=df_fastfood, x='경도', y='위도', hue='상호명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>
